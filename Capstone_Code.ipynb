# %% [markdown]
# ## Kansas City vs Austin: Which city is the best for video-game stores?

# %% [markdown]
# ### Capstone Code

# %% [markdown]
# First we import the necessary packages.

# %%
# !conda install -c conda-forge geopy --yes
# !conda install -c conda-forge folium=0.5.0 --yes

# library to handle requests
import requests
# library for data analsysis
import pandas as pd
# library to handle data in a vectorized manner
import numpy as np

# module to convert an address into latitude and longitude values
from geopy.geocoders import Nominatim

# libraries for displaying images
from IPython.display import Image 
from IPython.core.display import HTML 

# tranforming json file into a pandas dataframe library
from pandas.io.json import json_normalize

# plotting library
import folium

print('Libraries imported.')
# Out:
# Fetching package metadata .............
# Solving package specifications: .
#
# Package plan for installation in environment /opt/conda/envs/DSX-Python35:
#
# The following NEW packages will be INSTALLED:
#
#     geographiclib: 1.49-py_0   conda-forge
#     geopy:         1.19.0-py_0 conda-forge
#
# geographiclib- 100% |################################| Time: 0:00:00  24.77 MB/s
# geopy-1.19.0-p 100% |################################| Time: 0:00:00  37.03 MB/s
# Fetching package metadata .............
# Solving package specifications: .
#
# Package plan for installation in environment /opt/conda/envs/DSX-Python35:
#
# The following NEW packages will be INSTALLED:
#
#     altair:  2.2.2-py35_1 conda-forge
#     branca:  0.3.1-py_0   conda-forge
#     folium:  0.5.0-py_0   conda-forge
#     vincent: 0.4.4-py_1   conda-forge
#
# altair-2.2.2-p 100% |################################| Time: 0:00:00  45.97 MB/s
# branca-0.3.1-p 100% |################################| Time: 0:00:00  36.44 MB/s
# vincent-0.4.4- 100% |################################| Time: 0:00:00  40.26 MB/s
# folium-0.5.0-p 100% |################################| Time: 0:00:00  49.86 MB/s
# Libraries imported.

# %% [markdown]
# Next we define the Foursquare client ID and Secret, and Foursquare API version. Note that this information has been hidden after running.

# %%
CLIENT_ID = '*****'
CLIENT_SECRET = '*****'
VERSION = '20180604'

# %% [markdown]
# First let's analyze Kansas City.

# %%
address = 'Kansas City, MO'

geolocator = Nominatim(user_agent="foursquare_agent")
location = geolocator.geocode(address)
latitude = location.latitude
longitude = location.longitude
print(latitude, longitude)
# Out:
# 39.100105 -94.5781416

# %% [markdown]
# Our search query will be 'video games'. We will define a radius of 10000 meters from the city center and a limit of 50 venues. We add this information to the url, and then save our results as a json file.

# %%
search_query = 'Video Games'
radius = 10000
LIMIT = 50

url = 'https://api.foursquare.com/v2/venues/search?client_id={}&client_secret={}&ll={},{}&v={}&query={}&radius={}&limit={}'.format(CLIENT_ID, CLIENT_SECRET, latitude, longitude, VERSION, search_query, radius, LIMIT)

results = requests.get(url).json()

# %% [markdown]
# We assign the relevant parts of the json file to a variable called **venues**, and then transform it into **dataframe**.

# %%
venues = results['response']['venues']

dataframe = json_normalize(venues)

# %% [markdown]
# We will keep only the columns that include information to do with location, as well as the venue name. We then define a function that extracts the category of the venue, filter the category for each row, and clean the column names by changing them to only the last term.

# %%
filtered_columns = ['name', 'categories'] + [col for col in dataframe.columns if col.startswith('location.')] + ['id']
dataframe_mo = dataframe.loc[:, filtered_columns]

def get_category_type(row):
    try:
        categories_list = row['categories']
    except:
        categories_list = row['venue.categories']
        
    if len(categories_list) == 0:
        return None
    else:
        return categories_list[0]['name']

dataframe_mo['categories'] = dataframe_mo.apply(get_category_type, axis=1)

dataframe_mo.columns = [column.split('.')[-1] for column in dataframe_mo.columns]

dataframe_mo
# Out:
#                                     name             categories  \
# 0                         KC Video Games                 Arcade
# 1                         KC Video Games       Video Game Store
# 2                         emfluence, llc     Advertising Agency
# 3                            Kansas City     Miscellaneous Shop
# 4                            Video Mania            Video Store
# 5                            Video Mania  General Entertainment
# 6                    Level One Game Shop             Hobby Shop
# 7                 A to Z Video and Photo            Video Store
# 8                      Testimonial Video            Bridal Shop
# 9          Video Pros (Brookside Campus)                 Office
# 10  miss valeries house of drunken games           Cocktail Bar
# 11                   Mission Board Games            Gaming Cafe
# 12                    Miss G Video Shoot                 Church
# 13                      Go! Toys & Games       Toy / Game Store
# 14              SHAAZOOM  Biz Video Clip     Miscellaneous Shop
# 15                              GameStop       Video Game Store
# 16                      Perky Ones Games                Theater
# 17                              GameStop       Video Game Store
# 18   Kansas City Scottish Highland Games  General Entertainment
# 19                   Vicinity Games Inc.            Gaming Cafe
# 20                       worldwide video            Video Store
# 21                 Digital Video Midwest                   None
# 22                              Gamestop       Video Game Store
# 23                     Marble Zone Games                   None
# 24                              GameStop       Video Game Store
#
#                       address  cc          city        country  \
# 0   3909 Broadway Blvd Unit B  US   Kansas City  United States
# 1          3909 Broadway Blvd  US   Kansas City  United States
# 2           1720 Wyandotte St  US   Kansas City  United States
# 3                         NaN  US   Kansas City  United States
# 4             208 Westport Rd  US   Kansas City  United States
# 5             208 Westport Rd  US   Kansas City  United States
# 6        400 Grand Blvd #4020  US   Kansas City  United States
# 7           15 W Linwood Blvd  US   Kansas City  United States
# 8                         NaN  US   Kansas City  United States
# 9              6007 Cherry St  US   Kansas City  United States
# 10                        NaN  US   Kansas City  United States
# 11            5606 Johnson Dr  US       Mission  United States
# 12           115 N Denver Ave  US   Kansas City  United States
# 13                 Central St  US   Kansas City  United States
# 14                        NaN  US   Kansas City  United States
# 15            906 Westport Rd  US   Kansas City  United States
# 16                     Wanash  US   Kansas City  United States
# 17             500 Nichols Rd  US   Kansas City  United States
# 18                        NaN  US     Riverside  United States
# 19                        NaN  US           NaN  United States
# 20                        NaN  US   Kansas City  United States
# 21                        NaN  US   Kansas City  United States
# 22              5016 Roe Blvd  US  Roeland Park  United States
# 23            5739 Johnson Dr  US       Mission  United States
# 24       215B NE Englewood Rd  US   Kansas City  United States
#
#             crossStreet  distance  \
# 0                   NaN      4985
# 1                   NaN     10021
# 2          at W 18th St      1134
# 3                   NaN       896
# 4                   NaN      5572
# 5                   NaN      5223
# 6   btwn E 3rd & 5th St      1079
# 7                   NaN      3631
# 8                   NaN      4054
# 9               61st St      9125
# 10                  NaN      4984
# 11             Maple St     10666
# 12                  NaN      5366
# 13            Ward Pkwy      6689
# 14                  NaN      7008
# 15                  NaN      5741
# 16          52nd Street      7636
# 17   Country Club Plaza      6685
# 18                  NaN      7647
# 19                  NaN     10046
# 20                  NaN      9882
# 21                  NaN     10414
# 22                  NaN      8890
# 23                  NaN     10797
# 24         at North Oak     10472
#
#                                      formattedAddress  \
# 0   [3909 Broadway Blvd Unit B, Kansas City, MO 64...
# 1   [3909 Broadway Blvd, Kansas City, MO 64111, Un...
# 2   [1720 Wyandotte St (at W 18th St), Kansas City...
# 3              [Kansas City, MO 64106, United States]
# 4   [208 Westport Rd, Kansas City, MO 64111, Unite...
# 5   [208 Westport Rd, Kansas City, MO 64111, Unite...
# 6   [400 Grand Blvd #4020 (btwn E 3rd & 5th St), K...
# 7   [15 W Linwood Blvd, Kansas City, MO 64111, Uni...
# 8              [Kansas City, KS 66101, United States]
# 9   [6007 Cherry St (61st St), Kansas City, MO 641...
# 10             [Kansas City, MO 64116, United States]
# 11  [5606 Johnson Dr (Maple St), Mission, KS 66202...
# 12  [115 N Denver Ave, Kansas City, MO 64123, Unit...
# 13  [Central St (Ward Pkwy), Kansas City, MO 64112...
# 14             [Kansas City, MO 64112, United States]
# 15  [906 Westport Rd, Kansas City, MO 64111, Unite...
# 16  [Wanash (52nd Street), Kansas City, MO 64110, ...
# 17  [500 Nichols Rd (Country Club Plaza), Kansas C...
# 18               [Riverside, MO 64150, United States]
# 19                            [Kansas, United States]
# 20             [Kansas City, MO 64131, United States]
# 21                   [Kansas City, KS, United States]
# 22  [5016 Roe Blvd, Roeland Park, KS 66205, United...
# 23  [5739 Johnson Dr, Mission, KS 66202, United St...
# 24  [215B NE Englewood Rd (at North Oak), Kansas C...
#
#                                        labeledLatLngs        lat        lng  \
# 0   [{'label': 'display', 'lat': 39.0563634, 'lng'...  39.056363 -94.590511
# 1   [{'label': 'display', 'lat': 39.05261825014450...  39.052618 -94.676657
# 2   [{'label': 'display', 'lat': 39.09200527085377...  39.092005 -94.586115
# 3   [{'label': 'display', 'lat': 39.10553782024686...  39.105538 -94.570484
# 4   [{'label': 'display', 'lat': 39.05047596317046...  39.050476 -94.586543
# 5   [{'label': 'display', 'lat': 39.0539936940061,...  39.053994 -94.589310
# 6   [{'label': 'display', 'lat': 39.1094441, 'lng'...  39.109444 -94.581488
# 7   [{'label': 'display', 'lat': 39.06810631107306...  39.068106 -94.586310
# 8   [{'label': 'display', 'lat': 39.11426544189453...  39.114265 -94.621384
# 9   [{'label': 'display', 'lat': 39.01816, 'lng': ...  39.018160 -94.580960
# 10  [{'label': 'display', 'lat': 39.14441827797176...  39.144418 -94.569891
# 11  [{'label': 'display', 'lat': 39.022404, 'lng':...  39.022404 -94.650360
# 12  [{'label': 'display', 'lat': 39.11535680294037...  39.115357 -94.519211
# 13  [{'label': 'display', 'lat': 39.040767, 'lng':...  39.040767 -94.590348
# 14  [{'label': 'display', 'lat': 39.0382, 'lng': -...  39.038200 -94.592900
# 15  [{'label': 'display', 'lat': 39.05065798439998...  39.050658 -94.597047
# 16  [{'label': 'display', 'lat': 39.03354380466933...  39.033544 -94.556768
# 17  [{'label': 'display', 'lat': 39.04134472402195...  39.041345 -94.594158
# 18  [{'label': 'display', 'lat': 39.16243126261300...  39.162431 -94.615387
# 19  [{'label': 'display', 'lat': 39.02880101791968...  39.028801 -94.649391
# 20  [{'label': 'display', 'lat': 39.01138687133789...  39.011387 -94.573997
# 21  [{'label': 'display', 'lat': 39.0501345, 'lng'...  39.050134 -94.680019
# 22  [{'label': 'display', 'lat': 39.03721245831851...  39.037212 -94.641534
# 23  [{'label': 'display', 'lat': 39.02206413, 'lng...  39.022064 -94.652332
# 24  [{'label': 'display', 'lat': 39.19417564875638...  39.194176 -94.579427
#
#    postalCode   state                        id
# 0       64111      MO  58b774ac51d19e7f8b5212b0
# 1       64111      MO  54de2628498effd3ec244623
# 2       64108      MO  52a0d0f211d2e841f63dd513
# 3       64106      MO  52e9fb61498eeb50b69c0ed0
# 4       64111      MO  4de06eaec65bcc724f404a39
# 5       64111      MO  4c0ef7dc98102d7ff99ee406
# 6       64106      MO  583369e9e753566eaa9d3b41
# 7       64111      MO  51a682657dd21ca704e83b35
# 8       66101      KS  4fabc062e4b0d040d88e1b9f
# 9       64110      MO  4c87d126334537043e091672
# 10      64116      MO  4f9cc672e4b0d04dc0e12fbf
# 11      66202      KS  589f4a504bafb713bd6c9a0b
# 12      64123      MO  4dcea6bed4c065592f83c110
# 13      64112      MO  5c1ecff551950e002c7b6e1d
# 14      64112      MO  539591f3498e6b862b56137e
# 15      64111      MO  4b1b149cf964a520c8f723e3
# 16      64110      MO  4f516bd0e4b050039c7e6899
# 17      64112      MO  4b9591c9f964a520f7a934e3
# 18      64150      MO  4fd4ad74e4b0abd66573011a
# 19        NaN  Kansas  4e72b8da7d8b051837a4dd29
# 20      64131      MO  5070a87ce4b0e78a1a6bd7eb
# 21        NaN      KS  4db74173a86ed8d46c70c618
# 22      66205      KS  4aee6e4df964a520d3d321e3
# 23      66202      KS  4df93a48d22d964c6b99708c
# 24      64118      MO  4b75ed5bf964a5207b2f2ee3

# %% [markdown]
# Now we shall generate a map of Kansas City. We generate a map centered around the city center, add a red circle marker to represent the search area, and add the 'Video Games' venues as blue markers.

# %%
venues_map = folium.Map(location=[latitude, longitude], zoom_start=11)

folium.features.CircleMarker(
    [latitude, longitude],
    radius=200,
    color='red',
    fill = True,
    fill_color = 'red',
    fill_opacity = 0.1
).add_to(venues_map)

for lat, lng, label in zip(dataframe_mo.lat, dataframe_mo.lng, dataframe_mo.categories):
    folium.features.CircleMarker(
        [lat, lng],
        radius=5,
        color='blue',
        popup=label,
        fill = True,
        fill_color='blue',
        fill_opacity=0.6
    ).add_to(venues_map)

venues_map
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><iframe src="data:text/html;charset=utf-8;base64,..." style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" allowfullscreen webkitallowfullscreen mozallowfullscreen></iframe></div></div>

# %% [markdown]
# Next we make a list of the *IDs* of the venues. We use this to retrieve the rating of each venue, and then find the mean venue rating over Kansas City.

# %%
venue_ids_mo = dataframe_mo.id

venue_ratings_mo = []
for i in range(len(venue_ids_mo)):
    url = 'https://api.foursquare.com/v2/venues/{}?client_id={}&client_secret={}&v={}'.format(venue_ids_mo[i], CLIENT_ID, CLIENT_SECRET, VERSION)
    result = requests.get(url).json()
    try:
        venue_ratings_mo.append(result['response']['venue']['rating'])
    except:
        np.nan

mean_ratings_mo = np.mean(venue_ratings_mo)
mean_ratings_mo
# Out:
# 6.5999999999999996

# %% [markdown]
# Now we shall do all of the above for Austin, Texas.

# %%
address = 'Austin, TX'

geolocator = Nominatim(user_agent="foursquare_agent")
location = geolocator.geocode(address)
latitude = location.latitude
longitude = location.longitude
print(latitude, longitude)
# Out:
# 30.2711286 -97.7436995

# %%
search_query = 'Video Games'
radius = 10000
LIMIT = 50

url = 'https://api.foursquare.com/v2/venues/search?client_id={}&client_secret={}&ll={},{}&v={}&query={}&radius={}&limit={}'.format(CLIENT_ID, CLIENT_SECRET, latitude, longitude, VERSION, search_query, radius, LIMIT)

results = requests.get(url).json()

venues = results['response']['venues']

dataframe = json_normalize(venues)

filtered_columns = ['name', 'categories'] + [col for col in dataframe.columns if col.startswith('location.')] + ['id']
dataframe_filtered_tx = dataframe.loc[:, filtered_columns]

dataframe_filtered_tx['categories'] = dataframe_filtered_tx.apply(get_category_type, axis=1)

dataframe_filtered_tx.columns = [column.split('.')[-1] for column in dataframe_filtered_tx.columns]

dataframe_filtered_tx
# Out:
#                                                 name  \
# 0          Resurrected Movies, Video Games, and More
# 1                       Memory Tree Video Production
# 2                                          AHD Video
# 3                     Texas House Video Control Room
# 4                                       videotape.co
# 5                                       Cuervo Games
# 6                                          Videotape
# 7                                  Call4 Legal Video
# 8   Southwest Reporting & Video Service Inc - Austin
# 9                                        I Luv Video
# 10                            KW Agent Video Council
# 11                        Maccabi Games Loading Area
# 12                                Vulcan Video South
# 13                                 TapeLenders Video
# 14                     Austin Video Security Experts
# 15                       Signature Audio/Video Texas
# 16                              Kastle VideoGuarding
# 17                   Go! Toys & Games - Barton Creek
# 18                                       I Luv Video
# 19                                      Dreamers DVD
# 20                             UT Video Game Archive
# 21                                Horizon Film+Video
# 22                              Expressions in Video
# 23  District 5 Films | Weddings | Music Videos | Ads
# 24                            Tribe Comics and Games
# 25                            24 Hour Video and News
# 26                                 The Fittest Games
# 27                                       Video Super
# 28                           Whose Turn Is It? Games
# 29                               Steve Jackson Games
# 30                                       Pat's Games
# 31                  Carley Creative Video Production
# 32                     Emerald Tavern Games and Cafe
# 33                                      Video Mexico
# 34                              Prompt Video Creator
# 35                              Prompt Video Creator
# 36                              Access Video & Photo
# 37                              Game Over Videogames
# 38                                    Games Workshop
# 39                                          GameStop
# 40                                ProVideo Solutions
# 41                          Precision Camera & Video
# 42                          Putt Putt Golf and Games
# 43                                      Play N Trade
# 44                            Adult Video Megaplexxx
# 45                                          GameStop
# 46                                          GameStop
# 47                     Optic Bliss Video Productions
# 48                                         UPG Video
# 49                                Replay Games, Inc.
#
#                     categories                                   address  cc  \
# 0             Video Game Store                    2025 Guadalupe St #264  US
# 1                  Video Store  Frost Bank Tower, 401 Congress Ave #1540  US
# 2             Business Service                     209 E 6th St Ste 300D  US
# 3             Capitol Building                         101-199 W 15th St  US
# 4                  Music Venue                                       NaN  US
# 5        General Entertainment                                       4th  US
# 6                  Music Venue                                       NaN  US
# 7                 Tech Startup                          301 Congress Ave  US
# 8   Financial or Legal Service                  111 Congress Ave Ste 400  US
# 9                  Video Store                         4803 Airport Blvd  US
# 10             College Theater                                       NaN  US
# 11          Athletics & Sports                                       NaN  US
# 12                 Video Store                           4411 Russell Dr  US
# 13              Adult Boutique                             1114 W 5th St  US
# 14          Miscellaneous Shop                          1101 Navasota St  US
# 15                 Video Store                                       NaN  US
# 16            Business Service                  111 Congress Ave Ste 400  US
# 17            Toy / Game Store               2901 S Capital of Texas Hwy  US
# 18                 Video Store                         2915 Guadalupe St  US
# 19              Adult Boutique                      3401 N Interstate 35  US
# 20                 College Lab             University of Texas at Austin  US
# 21                      Office                         3405 Glenview Ave  US
# 22       General Entertainment                 1524 S Interstate 35 #160  US
# 23            Business Service                              2207 Leon St  US
# 24                  Comic Shop               3005 S Lamar Blvd Ste D-113  US
# 25                        None                           603 W Oltorf St  US
# 26                         Gym                             507 Calles St  US
# 27                 Video Store                                       NaN  US
# 28                  Hobby Shop                   2708 S Lamar Blvd #100B  US
# 29             Coworking Space                    Promontory Point Drive  US
# 30                  Hobby Shop                           2310 Hancock Dr  US
# 31       Entertainment Service                        5323 Levander Loop  US
# 32                 Gaming Cafe                        9012 Research Blvd  US
# 33                 Video Store                                       NaN  US
# 34            Business Service          2028 E Ben White Blvd # 240-2100  US
# 35                      Market          2028 E Ben White Blvd # 240-2100  US
# 36           Electronics Store                                       NaN  US
# 37            Video Game Store              3005 S Lamar Blvd Ste B-105B  US
# 38            Toy / Game Store                 4302 S Lamar Blvd Ste 600  US
# 39            Video Game Store             500 E Ben White Blvd Ste 1000  US
# 40           Electronics Store                     5808 Balcones Dr #102  US
# 41                Camera Store                 2438 W Anderson Ln Ste B4  US
# 42              Nightlife Spot                            6700 Burnet Rd  US
# 43            Video Game Store                  4301 W William Cannon Dr  US
# 44              Adult Boutique                      7111 S Interstate 35  US
# 45            Video Game Store                         6001 Airport Blvd  US
# 46            Video Game Store               2901 S Capital of Texas Hwy  US
# 47          Miscellaneous Shop                      6111 Bridlington Cir  US
# 48                Tech Startup                                       NaN  US
# 49                      Office                9211 Waterford Centre Blvd  US
#
#       city        country                                        crossStreet  \
# 0   Austin  United States                             Dobie Mall - 2nd Floor
# 1   Austin  United States                                                NaN
# 2   Austin  United States                                                NaN
# 3   Austin  United States                                                NaN
# 4   Austin  United States                                                NaN
# 5   Austin  United States                                          Guadalupe
# 6   Austin  United States                                                NaN
# 7   Austin  United States                                                NaN
# 8   Austin  United States                                                NaN
# 9   Austin  United States                                      E 48th 1/2 St
# 10  Austin  United States                                                NaN
# 11  Austin  United States                                                NaN
# 12  Austin  United States                                                NaN
# 13  Austin  United States                                                NaN
# 14  Austin  United States                                                NaN
# 15  Austin  United States                                                NaN
# 16  Austin  United States                                                NaN
# 17  Austin  United States                                      Mopac and 360
# 18  Austin  United States                                          Ｗ 29th St
# 19  Austin  United States                   btw Edgewood Ave & Concordia Ave
# 20  Austin  United States                                (Robert Dedman Dr.)
# 21  Austin  United States                                                NaN
# 22  Austin  United States                       Between Riverside & Congress
# 23  Austin  United States                                                NaN
# 24  Austin  United States                                                NaN
# 25  Austin  United States                                                NaN
# 26  Austin  United States                                                NaN
# 27  Austin  United States                                                NaN
# 28  Austin  United States                                                NaN
# 29  Austin  United States                                                NaN
# 30  Austin  United States                                                NaN
# 31  Austin  United States                                                NaN
# 32  Austin  United States                                          Burnet Rd
# 33     NaN  United States                                                NaN
# 34  Austin  United States                                                NaN
# 35  Austin  United States                                                NaN
# 36  Austin  United States                                                NaN
# 37  Austin  United States  south Lamar at Barton Skyway (near Kerby Ln Cafe)
# 38  Austin  United States                                                NaN
# 39  Austin  United States                           btw I-35 and S. Congress
# 40  Austin  United States                                                NaN
# 41  Austin  United States                                          Burnet Rd
# 42  Austin  United States                                                NaN
# 43  Austin  United States                                              Mopac
# 44  Austin  United States                                                NaN
# 45  Austin  United States                                                NaN
# 46  Austin  United States                                                NaN
# 47  Austin  United States                                                NaN
# 48  Austin  United States                                                NaN
# 49  Austin  United States                                                NaN
#
#     distance                                   formattedAddress  \
# 0       1404  [2025 Guadalupe St #264 (Dobie Mall - 2nd Floo...
# 1        461  [Frost Bank Tower, 401 Congress Ave #1540, Aus...
# 2        475  [209 E 6th St Ste 300D, Austin, TX 78701, Unit...
# 3        460  [101-199 W 15th St, Austin, TX 78701, United S...
# 4        954                        [Austin, TX, United States]
# 5        617       [4th (Guadalupe), Austin, TX, United States]
# 6        949                        [Austin, TX, United States]
# 7        641  [301 Congress Ave, Austin, TX 78701, United St...
# 8        797  [111 Congress Ave Ste 400, Austin, TX 78701, U...
# 9       4930  [4803 Airport Blvd (E 48th 1/2 St), Austin, TX...
# 10       917                        [Austin, TX, United States]
# 11      1135                        [Austin, TX, United States]
# 12      6347  [4411 Russell Dr, Austin, TX 78745, United Sta...
# 13      1316   [1114 W 5th St, Austin, TX 78703, United States]
# 14      1575  [1101 Navasota St, Austin, TX 78702, United St...
# 15      2725                  [Austin, TX 78702, United States]
# 16       824  [111 Congress Ave Ste 400, Austin, TX 78701, U...
# 17      6243  [2901 S Capital of Texas Hwy (Mopac and 360), ...
# 18      2771  [2915 Guadalupe St (Ｗ 29th St), Austin, TX 787...
# 19      3155  [3401 N Interstate 35 (btw Edgewood Ave & Conc...
# 20      2065  [University of Texas at Austin ((Robert Dedman...
# 21      4032  [3405 Glenview Ave, Austin, TX 78703, United S...
# 22      3227  [1524 S Interstate 35 #160 (Between Riverside ...
# 23      1760    [2207 Leon St, Austin, TX 78705, United States]
# 24      5078  [3005 S Lamar Blvd Ste D-113, Austin, TX 78704...
# 25      3574  [603 W Oltorf St, Austin, TX 78704, United Sta...
# 26      3426   [507 Calles St, Austin, TX 78702, United States]
# 27      8523                  [Austin, TX 78744, United States]
# 28      4615  [2708 S Lamar Blvd #100B, Austin, TX 78704, Un...
# 29      7067  [Promontory Point Drive, Austin, TX 78744, Uni...
# 30      5980  [2310 Hancock Dr, Austin, TX 78756, United Sta...
# 31      5141  [5323 Levander Loop, Austin, TX 78702, United ...
# 32     11307  [9012 Research Blvd (Burnet Rd), Austin, TX 78...
# 33     10978                             [Texas, United States]
# 34      5867  [2028 E Ben White Blvd # 240-2100, Austin, TX ...
# 35      6182  [2028 E Ben White Blvd # 240-2100, Austin, TX ...
# 36      6055                        [Austin, TX, United States]
# 37      5038  [3005 S Lamar Blvd Ste B-105B (south Lamar at ...
# 38      6160  [4302 S Lamar Blvd Ste 600, Austin, TX 78704, ...
# 39      5676  [500 E Ben White Blvd Ste 1000 (btw I-35 and S...
# 40      7593  [5808 Balcones Dr #102, Austin, TX 78731, Unit...
# 41      9716  [2438 W Anderson Ln Ste B4 (Burnet Rd), Austin...
# 42      8005  [6700 Burnet Rd, Austin, TX 78757, United States]
# 43     10807  [4301 W William Cannon Dr (Mopac), Austin, TX ...
# 44     10048  [7111 S Interstate 35, Austin, TX 78744, Unite...
# 45      6735  [6001 Airport Blvd, Austin, TX 78752, United S...
# 46      6328  [2901 S Capital of Texas Hwy, Austin, TX 78746...
# 47      8811  [6111 Bridlington Cir, Austin, TX 78745, Unite...
# 48      8819                  [Austin, TX 78752, United States]
# 49     11866  [9211 Waterford Centre Blvd, Austin, TX 78758,...
#
#                                        labeledLatLngs        lat        lng  \
# 0   [{'label': 'display', 'lat': 30.2835456849463,...  30.283546 -97.741132
# 1   [{'label': 'display', 'lat': 30.26702268120896...  30.267023 -97.743071
# 2   [{'label': 'display', 'lat': 30.26744429892386...  30.267444 -97.741199
# 3   [{'label': 'display', 'lat': 30.27475214855792...  30.274752 -97.741397
# 4   [{'label': 'display', 'lat': 30.266422, 'lng':...  30.266422 -97.735405
# 5   [{'label': 'display', 'lat': 30.26684, 'lng': ...  30.266840 -97.747776
# 6   [{'label': 'display', 'lat': 30.26644920618735...  30.266449 -97.735445
# 7   [{'label': 'display', 'lat': 30.26536862499706...  30.265369 -97.743559
# 8   [{'label': 'display', 'lat': 30.26398, 'lng': ...  30.263980 -97.744290
# 9   [{'label': 'display', 'lat': 30.30808163065903...  30.308082 -97.715430
# 10  [{'label': 'display', 'lat': 30.262894, 'lng':...  30.262894 -97.743224
# 11  [{'label': 'display', 'lat': 30.27950917279605...  30.279509 -97.736973
# 12  [{'label': 'display', 'lat': 30.22740853775097...  30.227409 -97.786080
# 13  [{'label': 'display', 'lat': 30.27175389090482...  30.271754 -97.757373
# 14  [{'label': 'display', 'lat': 30.26935313888934...  30.269353 -97.727444
# 15  [{'label': 'display', 'lat': 30.26440490432903...  30.264405 -97.716436
# 16  [{'label': 'display', 'lat': 30.26372146669203...  30.263721 -97.743650
# 17  [{'label': 'display', 'lat': 30.25763109867411...  30.257631 -97.806730
# 18  [{'label': 'display', 'lat': 30.2960049489496,...  30.296005 -97.742559
# 19  [{'label': 'display', 'lat': 30.29176380382098...  30.291764 -97.721187
# 20  [{'label': 'display', 'lat': 30.28930668227400...  30.289307 -97.739371
# 21  [{'label': 'display', 'lat': 30.30674382783061...  30.306744 -97.751371
# 22  [{'label': 'display', 'lat': 30.242822, 'lng':...  30.242822 -97.736432
# 23  [{'label': 'display', 'lat': 30.2861763, 'lng'...  30.286176 -97.749344
# 24  [{'label': 'display', 'lat': 30.24168856287966...  30.241689 -97.784041
# 25  [{'label': 'display', 'lat': 30.242116, 'lng':...  30.242116 -97.759627
# 26  [{'label': 'display', 'lat': 30.25849510594089...  30.258495 -97.711204
# 27  [{'label': 'display', 'lat': 30.194569, 'lng':...  30.194569 -97.745007
# 28  [{'label': 'display', 'lat': 30.24481764225627...  30.244818 -97.780793
# 29  [{'label': 'display', 'lat': 30.20912165141861...  30.209122 -97.727909
# 30  [{'label': 'display', 'lat': 30.32485118534138...  30.324851 -97.742943
# 31  [{'label': 'display', 'lat': 30.2501057, 'lng'...  30.250106 -97.696087
# 32  [{'label': 'display', 'lat': 30.37139302744759...  30.371393 -97.724869
# 33  [{'label': 'display', 'lat': 30.36711019443836...  30.367110 -97.717445
# 34  [{'label': 'display', 'lat': 30.22021186371718...  30.220212 -97.759480
# 35  [{'label': 'display', 'lat': 30.21570617200521...  30.215706 -97.739546
# 36  [{'label': 'display', 'lat': 30.323167, 'lng':...  30.323167 -97.725334
# 37  [{'label': 'display', 'lat': 30.24158986672108...  30.241590 -97.783404
# 38  [{'label': 'display', 'lat': 30.23689837083601...  30.236898 -97.794034
# 39  [{'label': 'display', 'lat': 30.22136360975917...  30.221364 -97.756573
# 40  [{'label': 'display', 'lat': 30.33850962875121...  30.338510 -97.756015
# 41  [{'label': 'display', 'lat': 30.35787047995563...  30.357870 -97.732420
# 42  [{'label': 'display', 'lat': 30.342911, 'lng':...  30.342911 -97.738565
# 43  [{'label': 'display', 'lat': 30.22063346785005...  30.220633 -97.839688
# 44  [{'label': 'display', 'lat': 30.18463498289811...  30.184635 -97.773591
# 45  [{'label': 'display', 'lat': 30.32581489999999...  30.325815 -97.713702
# 46  [{'label': 'display', 'lat': 30.25735705544280...  30.257357 -97.807563
# 47  [{'label': 'display', 'lat': 30.20658290506950...  30.206583 -97.796731
# 48  [{'label': 'display', 'lat': 30.34526167565929...  30.345262 -97.711320
# 49  [{'label': 'display', 'lat': 30.37697918167152...  30.376979 -97.729107
#
#    neighborhood postalCode  state                        id
# 0           NaN      78705     TX  4bb77d927421a5938e86c040
# 1           NaN      78701     TX  5784f325cd1041534cfcc425
# 2           NaN      78701     TX  54a710b5498e6e2f1e4148ee
# 3           NaN      78701     TX  4d87737c7e8ef04d668747be
# 4           NaN        NaN     TX  56e5dac6498e0feda74d6cc0
# 5           NaN        NaN     TX  4cc323b7b2beb1f7b3a0144c
# 6           NaN        NaN     TX  56da8d00498e53f5fde30328
# 7           NaN      78701     TX  52b36e4d11d20a39698e9fe0
# 8           NaN      78701     TX  54e82df5498e5760d33b8efd
# 9           NaN      78751     TX  4a6bc71ef964a520f0cf1fe3
# 10          NaN        NaN     TX  4e78c8038998834aa4470553
# 11          NaN        NaN     TX  51f545f0498e1f4d1d0d3543
# 12          NaN      78745     TX  57815d2f498ec67efada4afe
# 13          NaN      78703     TX  4b030359f964a520e54b22e3
# 14          NaN      78702     TX  5422e02d498ef501722de0df
# 15          NaN      78702     TX  59fbee41b3c961409c08feff
# 16          NaN      78701     TX  5cbe692d2619ee002cee1417
# 17          NaN      78746     TX  4e1e47b362840ee807401781
# 18          NaN      78705     TX  565df431498ec47524bac895
# 19          NaN      78722     TX  4bc9337968f976b0550e5d83
# 20          NaN      78731     TX  4df21c1888772e1f814e03b1
# 21          NaN      78703     TX  4f05ff987ee5ff2e8cf12816
# 22          NaN      78704     TX  4b674c0cf964a52082462be3
# 23          NaN      78705     TX  5630b093498e0af4ca126a7b
# 24          NaN      78704     TX  4acd0ea6f964a520afca20e3
# 25          NaN      78704     TX  4f32bf2119836c91c7f6077a
# 26          NaN      78702     TX  4f1aa85ae4b095bc44dab907
# 27          NaN      78744     TX  4ed3d4c24690a03b615b4d08
# 28          NaN      78704     TX  50672cabe4b073ee75f480ca
# 29          NaN      78744     TX  4b7ea88ff964a5209df72fe3
# 30          NaN      78756     TX  4b994f0bf964a520dd7135e3
# 31          NaN      78702     TX  589051568f0be469f0fc5831
# 32          NaN      78758     TX  514cc167e4b074491cf627a8
# 33          NaN        NaN  Texas  4bec5bc9fd60a5932fe33af1
# 34          NaN      78741     TX  55acb277498e5c282bf4ce4a
# 35          NaN      78741     TX  55a4f666498e48e87bdb81b6
# 36          NaN        NaN     TX  4da48a5f9aa4721e2c1a3a1a
# 37          NaN      78704     TX  4fff8b0febcaf0822d986e78
# 38          NaN      78704     TX  527eb1ea11d2816490ea48b4
# 39  St. Edwards      78704     TX  4bad4db4f964a52006443be3
# 40          NaN      78731     TX  57c91507498ea481109f07ce
# 41          NaN      78757     TX  49f7bd2af964a520d66c1fe3
# 42          NaN      78757     TX  4f32c4a019836c91c7f86991
# 43          NaN      78749     TX  4bca14ab3740b71357fe5f65
# 44          NaN      78744     TX  4dfe5a4562848aca58a2865b
# 45          NaN      78752     TX  4c8ffdf1b6d1a143f800c00f
# 46          NaN      78746     TX  4b969d90f964a520e8d834e3
# 47          NaN      78745     TX  555eb7c5498e54e2a78496ca
# 48          NaN      78752     TX  504f6113e4b077dc63114675
# 49          NaN      78758     TX  4b47a690f964a520063926e3

# %%
venues_map = folium.Map(location=[latitude, longitude], zoom_start=11)

folium.features.CircleMarker(
    [latitude, longitude],
    radius=200,
    color='red',
    fill = True,
    fill_color = 'red',
    fill_opacity = 0.1
).add_to(venues_map)

for lat, lng, label in zip(dataframe_filtered_tx.lat, dataframe_filtered_tx.lng, dataframe_filtered_tx.categories):
    folium.features.CircleMarker(
        [lat, lng],
        radius=5,
        color='blue',
        popup=label,
        fill = True,
        fill_color='blue',
        fill_opacity=0.6
    ).add_to(venues_map)

venues_map
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><iframe src="data:text/html;charset=utf-8;base64,..." style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" allowfullscreen webkitallowfullscreen mozallowfullscreen></iframe></div></div>

# %%
venue_ids_tx = dataframe_filtered_tx.id

venue_ratings_tx = []
for i in range(len(venue_ids_tx)):
    url = 'https://api.foursquare.com/v2/venues/{}?client_id={}&client_secret={}&v={}'.format(venue_ids_tx[i], CLIENT_ID, CLIENT_SECRET, VERSION)
    result = requests.get(url).json()
    try:
        venue_ratings_tx.append(result['response']['venue']['rating'])
    except:
        np.nan

mean_ratings_tx = np.mean(venue_ratings_tx)
mean_ratings_tx
# Out:
# 8.0357142857142847

# %% [markdown]
# Let's compare these ratings, and then we can solely deal with the dataframe and venues of the winning city.

# %%
if (mean_ratings_mo > mean_ratings_tx):
    print('We should go to Kansas City, Missouri!')
    df = dataframe_filtered_mo
else:
    print('We should go to Austin, Texas!')
    df = dataframe_filtered_tx

df.head()
# Out:
# We should go to Austin, Texas!
#                                         name        categories  \
# 0  Resurrected Movies, Video Games, and More  Video Game Store
# 1               Memory Tree Video Production       Video Store
# 2                                  AHD Video  Business Service
# 3             Texas House Video Control Room  Capitol Building
# 4                               videotape.co       Music Venue
#
#                                     address  cc    city        country  \
# 0                    2025 Guadalupe St #264  US  Austin  United States
# 1  Frost Bank Tower, 401 Congress Ave #1540  US  Austin  United States
# 2                     209 E 6th St Ste 300D  US  Austin  United States
# 3                         101-199 W 15th St  US  Austin  United States
# 4                                       NaN  US  Austin  United States
#
#               crossStreet  distance  \
# 0  Dobie Mall - 2nd Floor      1404
# 1                     NaN       461
# 2                     NaN       475
# 3                     NaN       460
# 4                     NaN       954
#
#                                     formattedAddress  \
# 0  [2025 Guadalupe St #264 (Dobie Mall - 2nd Floo...
# 1  [Frost Bank Tower, 401 Congress Ave #1540, Aus...
# 2  [209 E 6th St Ste 300D, Austin, TX 78701, Unit...
# 3  [101-199 W 15th St, Austin, TX 78701, United S...
# 4                        [Austin, TX, United States]
#
#                                       labeledLatLngs        lat        lng  \
# 0  [{'label': 'display', 'lat': 30.2835456849463,...  30.283546 -97.741132
# 1  [{'label': 'display', 'lat': 30.26702268120896...  30.267023 -97.743071
# 2  [{'label': 'display', 'lat': 30.26744429892386...  30.267444 -97.741199
# 3  [{'label': 'display', 'lat': 30.27475214855792...  30.274752 -97.741397
# 4  [{'label': 'display', 'lat': 30.266422, 'lng':...  30.266422 -97.735405
#
#   neighborhood postalCode state                        id
# 0          NaN      78705    TX  4bb77d927421a5938e86c040
# 1          NaN      78701    TX  5784f325cd1041534cfcc425
# 2          NaN      78701    TX  54a710b5498e6e2f1e4148ee
# 3          NaN      78701    TX  4d87737c7e8ef04d668747be
# 4          NaN        NaN    TX  56e5dac6498e0feda74d6cc0

# %% [markdown]
# Let's have a look at all the ratings of the venues of our winning city.

# %%
venue_ids = df.id

venue_ratings = []
for i in range(len(venue_ids)):
    url = 'https://api.foursquare.com/v2/venues/{}?client_id={}&client_secret={}&v={}'.format(venue_ids[i], CLIENT_ID, CLIENT_SECRET, VERSION)
    result = requests.get(url).json()
    try:
        venue_ratings.append(result['response']['venue']['rating'])
    except:
        venue_ratings.append(np.nan)

venue_ratings
# Out:
# [nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  8.8,
#  nan,
#  nan,
#  8.2,
#  6.0,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  6.8,
#  nan,
#  nan,
#  nan,
#  nan,
#  8.9,
#  nan,
#  nan,
#  nan,
#  8.1,
#  nan,
#  7.8,
#  nan,
#  9.0,
#  nan,
#  nan,
#  nan,
#  nan,
#  9.3,
#  nan,
#  8.6,
#  nan,
#  9.0,
#  nan,
#  nan,
#  7.7,
#  6.8,
#  7.5,
#  nan,
#  nan,
#  nan]

# %% [markdown]
# Now we shall add a category called *ratings* to our dataframe. Then we sort by ratings (highest on top), pick out the columns we are interested in, and drop the venues that don't have a zip code.

# %%
df['rating'] = venue_ratings

df = df.sort_values(by=['rating'], ascending=False)

df = df[['name','address','categories','postalCode','rating']]

df = df.dropna(subset = ['postalCode'])

df
# Out:
#                                                 name  \
# 37                              Game Over Videogames
# 32                     Emerald Tavern Games and Cafe
# 41                          Precision Camera & Video
# 24                            Tribe Comics and Games
# 9                                        I Luv Video
# 39                                          GameStop
# 12                                Vulcan Video South
# 28                           Whose Turn Is It? Games
# 30                                       Pat's Games
# 44                            Adult Video Megaplexxx
# 46                                          GameStop
# 19                                      Dreamers DVD
# 45                                          GameStop
# 13                                 TapeLenders Video
# 0          Resurrected Movies, Video Games, and More
# 1                       Memory Tree Video Production
# 2                                          AHD Video
# 3                     Texas House Video Control Room
# 7                                  Call4 Legal Video
# 8   Southwest Reporting & Video Service Inc - Austin
# 14                     Austin Video Security Experts
# 15                       Signature Audio/Video Texas
# 16                              Kastle VideoGuarding
# 17                   Go! Toys & Games - Barton Creek
# 18                                       I Luv Video
# 20                             UT Video Game Archive
# 21                                Horizon Film+Video
# 22                              Expressions in Video
# 23  District 5 Films | Weddings | Music Videos | Ads
# 25                            24 Hour Video and News
# 26                                 The Fittest Games
# 27                                       Video Super
# 29                               Steve Jackson Games
# 31                  Carley Creative Video Production
# 34                              Prompt Video Creator
# 35                              Prompt Video Creator
# 38                                    Games Workshop
# 40                                ProVideo Solutions
# 42                          Putt Putt Golf and Games
# 43                                      Play N Trade
# 47                     Optic Bliss Video Productions
# 48                                         UPG Video
# 49                                Replay Games, Inc.
#
#                                      address                  categories  \
# 37              3005 S Lamar Blvd Ste B-105B            Video Game Store
# 32                        9012 Research Blvd                 Gaming Cafe
# 41                 2438 W Anderson Ln Ste B4                Camera Store
# 24               3005 S Lamar Blvd Ste D-113                  Comic Shop
# 9                          4803 Airport Blvd                 Video Store
# 39             500 E Ben White Blvd Ste 1000            Video Game Store
# 12                           4411 Russell Dr                 Video Store
# 28                   2708 S Lamar Blvd #100B                  Hobby Shop
# 30                           2310 Hancock Dr                  Hobby Shop
# 44                      7111 S Interstate 35              Adult Boutique
# 46               2901 S Capital of Texas Hwy            Video Game Store
# 19                      3401 N Interstate 35              Adult Boutique
# 45                         6001 Airport Blvd            Video Game Store
# 13                             1114 W 5th St              Adult Boutique
# 0                     2025 Guadalupe St #264            Video Game Store
# 1   Frost Bank Tower, 401 Congress Ave #1540                 Video Store
# 2                      209 E 6th St Ste 300D            Business Service
# 3                          101-199 W 15th St            Capitol Building
# 7                           301 Congress Ave                Tech Startup
# 8                   111 Congress Ave Ste 400  Financial or Legal Service
# 14                          1101 Navasota St          Miscellaneous Shop
# 15                                       NaN                 Video Store
# 16                  111 Congress Ave Ste 400            Business Service
# 17               2901 S Capital of Texas Hwy            Toy / Game Store
# 18                         2915 Guadalupe St                 Video Store
# 20             University of Texas at Austin                 College Lab
# 21                         3405 Glenview Ave                      Office
# 22                 1524 S Interstate 35 #160       General Entertainment
# 23                              2207 Leon St            Business Service
# 25                           603 W Oltorf St                        None
# 26                             507 Calles St                         Gym
# 27                                       NaN                 Video Store
# 29                    Promontory Point Drive             Coworking Space
# 31                        5323 Levander Loop       Entertainment Service
# 34          2028 E Ben White Blvd # 240-2100            Business Service
# 35          2028 E Ben White Blvd # 240-2100                      Market
# 38                 4302 S Lamar Blvd Ste 600            Toy / Game Store
# 40                     5808 Balcones Dr #102           Electronics Store
# 42                            6700 Burnet Rd              Nightlife Spot
# 43                  4301 W William Cannon Dr            Video Game Store
# 47                      6111 Bridlington Cir          Miscellaneous Shop
# 48                                       NaN                Tech Startup
# 49                9211 Waterford Centre Blvd                      Office
#
#    postalCode  rating
# 37      78704     9.3
# 32      78758     9.0
# 41      78757     9.0
# 24      78704     8.9
# 9       78751     8.8
# 39      78704     8.6
# 12      78745     8.2
# 28      78704     8.1
# 30      78756     7.8
# 44      78744     7.7
# 46      78746     7.5
# 19      78722     6.8
# 45      78752     6.8
# 13      78703     6.0
# 0       78705     NaN
# 1       78701     NaN
# 2       78701     NaN
# 3       78701     NaN
# 7       78701     NaN
# 8       78701     NaN
# 14      78702     NaN
# 15      78702     NaN
# 16      78701     NaN
# 17      78746     NaN
# 18      78705     NaN
# 20      78731     NaN
# 21      78703     NaN
# 22      78704     NaN
# 23      78705     NaN
# 25      78704     NaN
# 26      78702     NaN
# 27      78744     NaN
# 29      78744     NaN
# 31      78702     NaN
# 34      78741     NaN
# 35      78741     NaN
# 38      78704     NaN
# 40      78731     NaN
# 42      78757     NaN
# 43      78749     NaN
# 47      78745     NaN
# 48      78752     NaN
# 49      78758     NaN

# %% [markdown]
# We can see that some of the categories don't seem correct. Let's manually pick out the categories that seem relevant.

# %%
final_df = df.loc[(df.categories == 'Video Game Store') | (df.categories == 'Gaming Cafe') | (df.categories == 'Hobby Shop') | (df.categories == 'Toy / Game Store')]

final_df
# Out:
#                                          name                        address  \
# 37                       Game Over Videogames   3005 S Lamar Blvd Ste B-105B
# 32              Emerald Tavern Games and Cafe             9012 Research Blvd
# 39                                   GameStop  500 E Ben White Blvd Ste 1000
# 28                    Whose Turn Is It? Games        2708 S Lamar Blvd #100B
# 30                                Pat's Games                2310 Hancock Dr
# 46                                   GameStop    2901 S Capital of Texas Hwy
# 45                                   GameStop              6001 Airport Blvd
# 0   Resurrected Movies, Video Games, and More         2025 Guadalupe St #264
# 17            Go! Toys & Games - Barton Creek    2901 S Capital of Texas Hwy
# 38                             Games Workshop      4302 S Lamar Blvd Ste 600
# 43                               Play N Trade       4301 W William Cannon Dr
#
#           categories postalCode  rating
# 37  Video Game Store      78704     9.3
# 32       Gaming Cafe      78758     9.0
# 39  Video Game Store      78704     8.6
# 28        Hobby Shop      78704     8.1
# 30        Hobby Shop      78756     7.8
# 46  Video Game Store      78746     7.5
# 45  Video Game Store      78752     6.8
# 0   Video Game Store      78705     NaN
# 17  Toy / Game Store      78746     NaN
# 38  Toy / Game Store      78704     NaN
# 43  Video Game Store      78749     NaN

# %% [markdown]
# Ultimately we are interested in the zip codes, as these will decide where we want to live. So finally we create a list of zip codes, ordered by venue rating.

# %%
where_to_live = final_df.postalCode
where_to_live = where_to_live.unique()

print('IMPORTANT ZIP CODES:')
print(where_to_live)
# Out:
# IMPORTANT ZIP CODES:
# ['78704' '78758' '78756' '78746' '78752' '78705' '78749']

# %% [markdown]
# ### This concludes our code.
